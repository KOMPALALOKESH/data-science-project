# %% [markdown]
# <a href="https://colab.research.google.com/github/KOMPALALOKESH/project-practice/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
# %matplotlib inline

# %%
df = pd.Series(data = [25,30,12,15,18])
df
# Out:
# ind    25
# eng    30
# aus    12
# pak    15
# afg    18
# dtype: int64

# %%
fig = plt.figure(figsize=(20,7))
plt.pie(df,autopct="%1.1f%%",explode=(0,0,0.1,0,0),shadow=True,labels=["ind","eng","aus","pak","afg"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f23f3795df0>,
#   <matplotlib.patches.Wedge at 0x7f23f37a84c0>,
#   <matplotlib.patches.Wedge at 0x7f23f37a8d90>,
#   <matplotlib.patches.Wedge at 0x7f23f37356a0>,
#   <matplotlib.patches.Wedge at 0x7f23f3735f70>],
#  [Text(0.7778174593052024, 0.7778174593052023, 'ind'),
#   Text(-0.8899187180267095, 0.6465637441936395, 'eng'),
#   Text(-0.9246158404836353, -0.764908849162265, 'aus'),
#   Text(-0.03455175057627758, -1.099457219054982, 'pak'),
#   Text(0.9287607875846771, -0.5894093649112565, 'afg')],
#  [Text(0.4242640687119285, 0.42426406871192845, '25.0%'),
#   Text(-0.48541020983275057, 0.3526711331965306, '30.0%'),
#   Text(-0.5393592402821206, -0.4461968286779878, '12.0%'),
#   Text(-0.018846409405242317, -0.5997039376663538, '15.0%'),
#   Text(0.5065967932280055, -0.3214960172243217, '18.0%')])
